# %% [markdown]
# <a href="https://colab.research.google.com/github/reynardofarreltj/ydata_profilling/blob/main/CollabData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Ganti 'nama_file.csv' dengan nama file yang kamu unduh
df = pd.read_csv('retail_store_sales.csv')

# Membuat laporan profil
profile = ProfileReport(df, title="Laporan Profiling Data Kotor")

# Menampilkan laporan di notebook (misalnya, Jupyter)
# profile.to_widgets()

# Atau menyimpan laporan sebagai file HTML
profile.to_file("laporan_profiling.html")

# Alternatif dari to_widgets()
profile.to_notebook_iframe()
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
# !pip install ydata-profiling
